# %% [markdown]
# <a href="https://colab.research.google.com/github/leoliv3ira/graficCodes/blob/main/GraficosPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXEMPLOS DE CÓDIGOS EM PYTHON DE CRIAÇÃO DE GRAFICOS 📈 :

# %% [markdown]
# **Gráfico boxplot**

# %%
# Exemplo de codigo para grafico boxplot.
import matplotlib.pyplot as plt
import numpy as np
import statistics as sta

lista = [10,20,20,24,28,28,30,32,32,32,36,40,43,56,60]

mediana = np.median(lista)
media = np.average(lista)
moda = sta.mode(lista)
q1 = np.percentile(lista, 25, method="midpoint")
q3 = np.percentile(lista, 75, method="midpoint")
I = (q3 - q1)
min = q1 - 1.5*I
max = q3 + 1.5*I

outlier = []
for i in range(len(lista)):
  if lista[i] > max or lista[i] < min:
    outlier.append(lista[i])

print(f"mediana = {mediana}")
print(f"media = {media}")
print(f"moda = {moda}")
print(f"1° quartil = {q1}")
print(f"3° quartil = {q3}")
print(f"I = {I}")
print(f"min = {min}")
print(f"max = {max}")
print(f"Outlier ={outlier}")

plt.boxplot(lista, vert = False)
#plt.savefig("grafico boxplot.png")
plt.show()
# Out:
# mediana = 32.0
# media = 32.733333333333334
# moda = 32
# 1° quartil = 26.0
# 3° quartil = 38.0
# I = 12.0
# min = 8.0
# max = 56.0
# Outlier =[60]

# %% [markdown]
# **Gráfico de Barras**

# %%
# exemplo de codigo para grafico de barras
import matplotlib.pyplot as plt
import numpy as np

x = ["Vira-lata", "Golden", "Shitzu", "Labrador", "Pitbull"]
y = [25, 13, 7, 17, 21]

cores = ["red", "yellow", "silver", "black", "blue"]

plt.bar(x, y, color = cores)
plt.title("Raças de Cachorro adotados em janeiro", color= "black")
plt.ylabel("Quantidade", color= "black")
plt.xlabel("Raças de cachorro", color="black")
plt.ylim([0,30])

for i, val in enumerate (y):
  texto = f"{val} "
  y_coord = val + 1
  x_coord = i - 0.1
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize=10)

plt.show()
#plt.savefig("Grafico de barras.png)

# %% [markdown]
# **Gráfico de linhas**

# %%
# exemplo de codigo de grafico de linhas
import matplotlib.pyplot as plt
import numpy as np

acaoA = [30,70,190,110,230,310,350,150,350,390,410,400]
acaoB = [100,250,400,200,350,500,150,300,350,370,320,330]
mes = ["janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"]


plt.figure(figsize=(15, 6))

for i, val in enumerate(acaoA):
  texto = f"{val} "
  x_coord = i - 0.3
  y_coord = val + 4
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize= 10)

for i, val in enumerate(acaoB):
  texto = f"{val} "
  x_coord = i -0.3
  y_coord = val + 4
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize= 10)


plt.plot(mes, acaoA,
         marker = "o",
         color = "red",
         linestyle = "--",
         linewidth = 2,
         label = "Ação A",)
plt.plot(mes, acaoB,
         marker = "o",
         color = "blue",
         label = "Ação B")


plt.title("Açôes no ano de 2023", color ="black")
plt.ylim([0,700])
plt.legend(loc = "upper left")
plt.grid()
#plt.figure(facecolor ="brown")
#plt.axes().set_facecolor("#FFE7BA")
#plt.savefig("grafico de linhas.png")
plt.show()

# %% [markdown]
# **Gráfico de pizza**

# %%
# exemplo de codigo para grafico de pizza(setores)

sabores = ["calabresa","queijo","vegetais","carne","outros"]
qtd = [30,25,17,13,20]

cores = ["red","yellow","green","brown","blue"]

plt.pie(qtd, labels = sabores, autopct= "%5.1f%%", colors = cores )
#plt.savefig("grafico de pizza.png")
plt.show()

# %% [markdown]
# **Gráfico de barras com linha**

# %%
# codigo grafico de barras com linha
import numpy as np
import matplotlib.pyplot as plt

nomes = ["Adriana Alves","Adriana Souza", "Alessandra Ramos","Aline Duarte",
         "Ana Cristina", "Ana Lucia", "Ana Paula","Andreia Lima", "Andressa Paula"]
nota = [66.7, 86.0, 46.0, 95.0, 95.0, 90.5, 78.0, 94.0, 88.0]
media = [70.0, 70.0, 70.0, 70.0, 70.0, 70.0, 70.0, 70.0, 70.0]

cores = ['blue','blue','blue','blue','blue','blue','blue','blue','blue']

plt.figure(figsize=(15, 6))
plt.bar(nomes, nota, color = cores)
plt.title("Media de notas das alunas", color = 'black')
plt.ylim([0,120])
plt.ylabel("Media nota", color = 'black')

plt.plot(media,
         color = "red",
         linewidth = 3,
         label = 'Media Esperada(70.0)')


#Pegando os numeros de cadad variavel e colocando no grafico
for i, val in enumerate (nota):
  texto = f"{val} "
  y_coord = val + 1
  x_coord = i - 0.1
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize=10)
  plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics as sta

idade = [30, 40, 54, 20, 10, 17, 32, 27, 61, 20, 15]
nome= ['Jorge', 'Ana', 'Joao', 'Isabela', 'Leonardo', 'Rita', 'Catarina', 'Lucas', 'Elenilto', 'Maria', 'Ernesto']

plt.figure(figsize=(12,6))
for i, val in enumerate (idade):
  texto = f"{val} "
  y_coord = val + 1
  x_coord = i - 0.1
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize=10)

plt.ylabel('IDADE')
plt.bar(nome, idade , color='Green')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

vendasCamiseta = [20, 25, 17, 19, 37, 29, 35, 19, 22, 28, 34, 47]
vendasBermudas = [10, 13, 15, 12, 24, 20, 18, 16, 15, 23, 29, 31]

meses = ['JAN', 'FEV', 'MAR', 'ABR', 'MAI', 'JUN', 'JUL', 'AGO', 'SET','OUT', 'NOV', 'DEZ']

for i, val in enumerate (vendasCamiseta):
  texto = f"{val} "
  y_coord = val + 2
  x_coord = i - 0.3
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize=10)

for i, val in enumerate (vendasBermudas):
  texto = f"{val} "
  y_coord = val - 3
  x_coord = i - 0.1
  plt.text(x=x_coord, y=y_coord, s=texto, fontsize=10)

plt.plot(meses, vendasCamiseta,
         marker = 'o',
         color = 'Black',
         linewidth = 2,
         label = 'Camisetas')
plt.plot(meses, vendasBermudas,
         marker = 'o',
         color = 'blue',
         linewidth = 2,
         label = 'Bermudas')

plt.xlabel('Meses')
plt.ylabel('Quantidade Vendas')
plt.ylim([0, 50])
plt.legend(loc='upper left')
plt.title('vendas do ano 2024')

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

produto = ['cueca', 'calça', 'meia', 'calcinha', 'sutiã', 'blusa']
qntVendas = [57, 80, 62, 53, 31, 27]

cores = ['blue', 'red', 'green', 'purple', 'orange', 'yellow']

plt.pie(qntVendas, labels = produto, autopct = '%5.1f%%', colors = cores)
plt.title('Porcentagem de vendas dos produtos no ano de 2023')
plt.show()
